# %% [markdown]
# <a href="https://colab.research.google.com/github/GokulDas027/ML-Codes/blob/master/Image%20Classifier%20Pretrained%20VGG-16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='https://github.com/udacity/pytorch_challenge/blob/master/assets/Flowers.png?raw=1' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content

# %%
# colab needs
# !pip install Pillow==4.0.0
# Out:
# Collecting Pillow==4.0.0
#   Downloading https://files.pythonhosted.org/packages/37/e8/b3fbf87b0188d22246678f8cd61e23e31caa1769ebc06f1664e2e5fe8a17/Pillow-4.0.0-cp36-cp36m-manylinux1_x86_64.whl (5.6MB)
#      |████████████████████████████████| 5.6MB 28kB/s
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from Pillow==4.0.0) (0.46)
# ERROR: torchvision 0.2.2.post3 has requirement pillow>=4.1.1, but you'll have pillow 4.0.0 which is incompatible.
# ERROR: scikit-image 0.14.2 has requirement pillow>=4.3.0, but you'll have pillow 4.0.0 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: Pillow
#   Found existing installation: Pillow 4.3.0
#     Uninstalling Pillow-4.3.0:
#       Successfully uninstalled Pillow-4.3.0
# Successfully installed Pillow-4.0.0

# %%
# imports
import torch
from torchvision import transforms,models,datasets
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
import seaborn as sb


# %matplotlib inline

# %%
# check if CUDA is available
train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
    print('CUDA is not available.  Training on CPU ...')
else:
    print('CUDA is available!  Training on GPU ...')
# Out:
# CUDA is available!  Training on GPU ...

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). You can [download the data here](https://s3.amazonaws.com/content.udacity-data.com/courses/nd188/flower_data.zip). The dataset is split into two parts, training and validation. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. If you use a pre-trained network, you'll also need to make sure the input data is resized to 224x224 pixels as required by the networks.
#
# The validation set is used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks available from `torchvision` were trained on the ImageNet dataset where each color channel was normalized separately. For both sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
# downloading dataset
# !wget "https://s3.amazonaws.com/content.udacity-data.com/courses/nd188/flower_data.zip"
# Out:
# --2019-05-13 13:16:57--  https://s3.amazonaws.com/content.udacity-data.com/courses/nd188/flower_data.zip
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.232.77
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.232.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 311442766 (297M) [application/zip]
# Saving to: ‘flower_data.zip’
#
# flower_data.zip     100%[===================>] 297.01M  86.6MB/s    in 3.4s
#
# 2019-05-13 13:17:01 (86.7 MB/s) - ‘flower_data.zip’ saved [311442766/311442766]

# %%
#unzip the downloaded dataset
import zipfile
with zipfile.ZipFile("flower_data.zip","r") as zip_ref:
    zip_ref.extractall()

# %%
im = plt.imread('flower_data/train/1/image_06734.jpg')
plt.imshow(im)

# %%
data_dir = 'flower_data'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'

# %%
# no. of subprocesses to use for data loading
num_workers = 4
# samples per batch to load
batch_size = 20


data_transforms = {'train':transforms.Compose([
                       transforms.Resize(256),
                       transforms.CenterCrop(224),
                       transforms.RandomRotation(30),
                       transforms.RandomHorizontalFlip(),
                       transforms.ToTensor(),
                       transforms.Normalize([0.485, 0.456, 0.406],[0.229, 0.224, 0.225])]),
                   'valid':transforms.Compose([
                       transforms.Resize(256),
                       transforms.CenterCrop(224),
                       transforms.ToTensor(),
                       transforms.Normalize([0.485, 0.456, 0.406],[0.229, 0.224, 0.225])])}

# TODO: Load the datasets with ImageFolder
train_data = datasets.ImageFolder(train_dir,transform=data_transforms['train'])
valid_data = datasets.ImageFolder(valid_dir,transform=data_transforms['valid'])

# TODO: Using the image datasets and the trainforms, define the dataloaders
train_loader = torch.utils.data.DataLoader(train_data,batch_size=batch_size,num_workers=num_workers,shuffle=True)
valid_loader = torch.utils.data.DataLoader(valid_data,batch_size=batch_size,num_workers=num_workers,shuffle=True)

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
# !wget -cq https://github.com/udacity/pytorch_challenge/raw/master/cat_to_name.json

# %%
import json

with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. If you want to talk through it with someone, chat with your fellow students! You can also ask questions on the forums or join the instructors in office hours.
#
# Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.

# %%
# TODO: Build and train your network
model = models.vgg16(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/checkpoints/vgg16-397923af.pth
# 100%|██████████| 553433881/553433881 [00:05<00:00, 107589490.55it/s]

# %%
# freezing the model parameters
for param in model.parameters():
  param.requires_grad=False
  
model
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace)
#     (2): Dropout(p=0.5)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace)
#     (5): Dropout(p=0.5)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %%
# adding classifer layer to model  
model.classifier = nn.Sequential(nn.Linear(25088,4096),
                                 nn.ReLU(),
                                 nn.Dropout(0.6),
                                 nn.Linear(4096,102))

if train_on_gpu:
    model.cuda()
model
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.6)
#     (3): Linear(in_features=4096, out_features=102, bias=True)
#   )
# )

# %%
# loss function
criterion = nn.CrossEntropyLoss()

# optimizer
optimizer = optim.SGD(model.classifier.parameters(), lr=0.001, momentum=0.5)

# %%
# training
epoch=40

for e in range(epoch):
  train_loss = 0.0
  train_correct = 0
  valid_loss = 0.0
  valid_correct = 0
  for data,target in train_loader:
    if train_on_gpu:
      data,target=data.cuda(),target.cuda()
    
    optimizer.zero_grad()
    model.train()
    
    output=model(data)
    _, preds = torch.max(output, 1)
    loss=criterion(output,target)
    loss.backward()
    optimizer.step()
    train_loss += loss.item()*data.size(0)
    train_correct += torch.sum(preds == target.data)
    
  model.eval()
  for data,target in valid_loader:
    if train_on_gpu:
      data,target=data.cuda(),target.cuda()
    
    output=model(data)
    _, preds = torch.max(output, 1)
    loss=criterion(output,target)
    valid_loss += loss.item()*data.size(0)
    valid_correct += torch.sum(preds == target.data)
    
  train_loss = train_loss/len(train_loader.dataset)
  train_correct = train_correct.double()/len(train_loader.dataset)
  valid_loss = valid_loss/len(valid_loader.dataset)
  valid_correct = valid_correct.double()/len(valid_loader.dataset)
  
  print(f'Epoch:{e+1}/{epoch} Training-> Loss:{train_loss} Accuracy:{train_correct}'
        f'_Validation-> Loss:{valid_loss} Accuracy:{valid_correct}')
# Out:
# Epoch:1/40 Training-> Loss:3.738678368602189 Accuracy:0.22313797313797315_Validation-> Loss:2.8522066796029986 Accuracy:0.46454767726161367
# Epoch:2/40 Training-> Loss:2.297210931996286 Accuracy:0.5216727716727717_Validation-> Loss:1.8401838984058072 Accuracy:0.6515892420537898
# Epoch:3/40 Training-> Loss:1.5589236475536383 Accuracy:0.6688034188034188_Validation-> Loss:1.3748645671713906 Accuracy:0.7432762836185819
# Epoch:4/40 Training-> Loss:1.1667881797230433 Accuracy:0.7467948717948718_Validation-> Loss:1.1014241592225351 Accuracy:0.7872860635696821
# Epoch:5/40 Training-> Loss:0.9427695434281241 Accuracy:0.7942612942612942_Validation-> Loss:0.902332346713339 Accuracy:0.8325183374083129
# Epoch:6/40 Training-> Loss:0.8021102205592052 Accuracy:0.826007326007326_Validation-> Loss:0.8189581593266326 Accuracy:0.8349633251833741
# Epoch:7/40 Training-> Loss:0.6900648983406933 Accuracy:0.8427960927960928_Validation-> Loss:0.7218351434816067 Accuracy:0.8447432762836186
# Epoch:8/40 Training-> Loss:0.5990973326294559 Accuracy:0.8666056166056166_Validation-> Loss:0.6751322558281766 Accuracy:0.8533007334963325
# Epoch:9/40 Training-> Loss:0.5348607136598437 Accuracy:0.8846153846153846_Validation-> Loss:0.625026102753898 Accuracy:0.8618581907090465
# Epoch:10/40 Training-> Loss:0.48190132334773794 Accuracy:0.8933150183150184_Validation-> Loss:0.5925782382633983 Accuracy:0.8643031784841075
# Epoch:11/40 Training-> Loss:0.4475136775164086 Accuracy:0.900946275946276_Validation-> Loss:0.5616120718656368 Accuracy:0.8691931540342298
# Epoch:12/40 Training-> Loss:0.40516916318126794 Accuracy:0.9120879120879121_Validation-> Loss:0.5402661565609258 Accuracy:0.8704156479217604
# Epoch:13/40 Training-> Loss:0.37307666110896004 Accuracy:0.9174297924297924_Validation-> Loss:0.520339873790158 Accuracy:0.8765281173594132
# Epoch:14/40 Training-> Loss:0.34088223324281247 Accuracy:0.9250610500610501_Validation-> Loss:0.5010388941665733 Accuracy:0.8814180929095354
# Epoch:15/40 Training-> Loss:0.32322201277874185 Accuracy:0.9323870573870574_Validation-> Loss:0.48669871680602467 Accuracy:0.8850855745721271
# Epoch:16/40 Training-> Loss:0.31408305607636045 Accuracy:0.9302503052503053_Validation-> Loss:0.4658189699381663 Accuracy:0.8948655256723717
# Epoch:17/40 Training-> Loss:0.2868116764904379 Accuracy:0.9384920634920635_Validation-> Loss:0.4490686059726771 Accuracy:0.8948655256723717
# Epoch:18/40 Training-> Loss:0.27836750979479563 Accuracy:0.9426129426129426_Validation-> Loss:0.44602005792130467 Accuracy:0.8948655256723717
# Epoch:19/40 Training-> Loss:0.2624827176855561 Accuracy:0.9413919413919414_Validation-> Loss:0.4335017609421373 Accuracy:0.902200488997555
# Epoch:20/40 Training-> Loss:0.24352806600513477 Accuracy:0.9514652014652014_Validation-> Loss:0.4261670589155556 Accuracy:0.8973105134474327
# Epoch:21/40 Training-> Loss:0.2281963393019378 Accuracy:0.9523809523809523_Validation-> Loss:0.419394610709258 Accuracy:0.8997555012224939
# Epoch:22/40 Training-> Loss:0.21519877885551317 Accuracy:0.9572649572649573_Validation-> Loss:0.41262443454749426 Accuracy:0.902200488997555
# Epoch:23/40 Training-> Loss:0.20321855822211912 Accuracy:0.958943833943834_Validation-> Loss:0.4013961124026688 Accuracy:0.9058679706601467
# Epoch:24/40 Training-> Loss:0.19343858124331204 Accuracy:0.9607753357753358_Validation-> Loss:0.39550299705677916 Accuracy:0.8997555012224939
# Epoch:25/40 Training-> Loss:0.18491726363434824 Accuracy:0.9632173382173382_Validation-> Loss:0.38986923456337746 Accuracy:0.9058679706601467
# Epoch:26/40 Training-> Loss:0.1800216774072985 Accuracy:0.9616910866910867_Validation-> Loss:0.3928571103327432 Accuracy:0.9034229828850856
# Epoch:27/40 Training-> Loss:0.17489010236829847 Accuracy:0.963980463980464_Validation-> Loss:0.385870806599596 Accuracy:0.9144254278728606
# Epoch:28/40 Training-> Loss:0.16471056901236886 Accuracy:0.9662698412698413_Validation-> Loss:0.37853152937003043 Accuracy:0.9144254278728606
# Epoch:29/40 Training-> Loss:0.1565519811060184 Accuracy:0.9682539682539683_Validation-> Loss:0.37948314721689247 Accuracy:0.902200488997555
# Epoch:30/40 Training-> Loss:0.15253548296646047 Accuracy:0.9716117216117216_Validation-> Loss:0.370749414295031 Accuracy:0.9083129584352079
# Epoch:31/40 Training-> Loss:0.14292813240867722 Accuracy:0.9742063492063492_Validation-> Loss:0.36888461028086816 Accuracy:0.9193154034229829
# Epoch:32/40 Training-> Loss:0.14529774335846396 Accuracy:0.9720695970695971_Validation-> Loss:0.37631811788146247 Accuracy:0.902200488997555
# Epoch:33/40 Training-> Loss:0.13320465329625122 Accuracy:0.974969474969475_Validation-> Loss:0.36838245963846267 Accuracy:0.9156479217603912
# Epoch:34/40 Training-> Loss:0.13033653062203118 Accuracy:0.9763431013431013_Validation-> Loss:0.3618638887090613 Accuracy:0.9119804400977995
# Epoch:35/40 Training-> Loss:0.12207585426561435 Accuracy:0.979090354090354_Validation-> Loss:0.36529150299163204 Accuracy:0.91320293398533
# Epoch:36/40 Training-> Loss:0.12065127778682352 Accuracy:0.9771062271062271_Validation-> Loss:0.360033982977599 Accuracy:0.9070904645476773
# Epoch:37/40 Training-> Loss:0.11683172698534107 Accuracy:0.9795482295482295_Validation-> Loss:0.3481261002259616 Accuracy:0.9193154034229829
# Epoch:38/40 Training-> Loss:0.11872625390240543 Accuracy:0.9781746031746031_Validation-> Loss:0.35078510769567744 Accuracy:0.9144254278728606
# Epoch:39/40 Training-> Loss:0.10773906007554651 Accuracy:0.9822954822954822_Validation-> Loss:0.349149100172782 Accuracy:0.9168704156479217
# Epoch:40/40 Training-> Loss:0.1059489598775212 Accuracy:0.9816849816849816_Validation-> Loss:0.34684091739010403 Accuracy:0.9156479217603912

# %% [markdown]
# ## Testing the Classifier on a new test set

# %%
# !git clone https://github.com/cahya-wirawan/Udacity-Course/
# Out:
# Cloning into 'Udacity-Course'...
# remote: Enumerating objects: 73, done.
# remote: Counting objects: 100% (73/73), done.
# remote: Compressing objects: 100% (57/57), done.
# remote: Total 73 (delta 30), reused 53 (delta 15), pack-reused 0
# Unpacking objects: 100% (73/73), done.

# %%
# %%bash
# tar -xvzf 'Udacity-Course/flower_test.tgz'
# ls
# Out:
# test/
# test/88/
# test/88/image_00467.jpg
# test/88/image_00474.jpg
# test/88/image_00582.jpg
# test/88/image_00482.jpg
# test/88/image_00594.jpg
# test/88/image_00540.jpg
# test/88/image_00520.jpg
# test/88/image_00551.jpg
# test/88/image_00526.jpg
# test/88/image_00563.jpg
# test/88/image_00477.jpg
# test/88/image_00457.jpg
# test/88/image_00584.jpg
# test/42/
# test/42/image_05696.jpg
# test/42/image_05730.jpg
# test/42/image_05711.jpg
# test/42/image_05731.jpg
# test/5/
# test/5/image_05166.jpg
# test/5/image_05169.jpg
# test/5/image_05159.jpg
# test/5/image_05186.jpg
# test/94/
# test/94/image_07415.jpg
# test/94/image_07308.jpg
# test/94/image_07358.jpg
# test/94/image_07352.jpg
# test/94/image_07399.jpg
# test/94/image_07333.jpg
# test/94/image_07395.jpg
# test/94/image_07361.jpg
# test/94/image_07388.jpg
# test/94/image_07370.jpg
# test/94/image_07346.jpg
# test/94/image_07434.jpg
# test/94/image_07400.jpg
# test/94/image_07436.jpg
# test/94/image_07357.jpg
# test/94/image_07327.jpg
# test/16/
# test/16/image_06670.jpg
# test/16/image_06673.jpg
# test/16/image_06657.jpg
# test/36/
# test/36/image_04373.jpg
# test/36/image_04364.jpg
# test/36/image_04392.jpg
# test/36/image_04334.jpg
# test/36/image_04400.jpg
# test/36/image_04382.jpg
# test/36/image_04344.jpg
# test/32/
# test/32/image_05614.jpg
# test/32/image_05602.jpg
# test/32/image_05591.jpg
# test/32/image_05592.jpg
# test/32/image_05610.jpg
# test/32/image_05595.jpg
# test/12/
# test/12/image_04052.jpg
# test/12/image_04023.jpg
# test/12/image_04012.jpg
# test/12/image_04059.jpg
# test/12/image_03996.jpg
# test/12/image_04016.jpg
# test/12/image_04077.jpg
# test/12/image_03994.jpg
# test/12/image_04014.jpg
# test/74/
# test/74/image_01256.jpg
# test/74/image_01312.jpg
# test/74/image_01254.jpg
# test/74/image_01209.jpg
# test/74/image_01307.jpg
# test/74/image_01213.jpg
# test/74/image_01305.jpg
# test/74/image_01249.jpg
# test/74/image_01191.jpg
# test/74/image_01151.jpg
# test/74/image_01173.jpg
# test/74/image_01200.jpg
# test/74/image_01165.jpg
# test/74/image_01276.jpg
# test/2/
# test/2/image_05107.jpg
# test/2/image_05100.jpg
# test/2/image_05133.jpg
# test/2/image_05125.jpg
# test/2/image_05109.jpg
# test/77/
# test/77/image_00060.jpg
# test/77/image_00006.jpg
# test/77/image_00212.jpg
# test/77/image_00025.jpg
# test/77/image_00092.jpg
# test/77/image_00029.jpg
# test/77/image_00114.jpg
# test/77/image_00222.jpg
# test/77/image_00203.jpg
# test/77/image_00116.jpg
# test/77/image_00191.jpg
# test/77/image_00177.jpg
# test/77/image_00187.jpg
# test/77/image_00005.jpg
# test/77/image_00132.jpg
# test/77/image_00176.jpg
# test/77/image_00099.jpg
# test/77/image_00248.jpg
# test/77/image_00239.jpg
# test/77/image_00202.jpg
# test/77/image_00065.jpg
# test/77/image_00024.jpg
# test/77/image_00204.jpg
# test/77/image_00251.jpg
# test/77/image_00050.jpg
# test/46/
# test/46/image_01071.jpg
# test/46/image_01125.jpg
# test/46/image_01026.jpg
# test/46/image_01061.jpg
# test/46/image_01090.jpg
# test/46/image_00976.jpg
# test/46/image_00969.jpg
# test/46/image_01092.jpg
# test/46/image_00999.jpg
# test/46/image_01038.jpg
# test/46/image_00961.jpg
# test/46/image_01077.jpg
# test/46/image_01003.jpg
# test/46/image_00970.jpg
# test/46/image_00990.jpg
# test/46/image_01119.jpg
# test/46/image_01078.jpg
# test/46/image_00996.jpg
# test/46/image_01115.jpg
# test/46/image_01109.jpg
# test/46/image_00958.jpg
# test/82/
# test/82/image_01672.jpg
# test/82/image_01685.jpg
# test/82/image_01686.jpg
# test/82/image_01679.jpg
# test/82/image_01609.jpg
# test/82/image_01610.jpg
# test/82/image_01599.jpg
# test/82/image_01650.jpg
# test/82/image_01666.jpg
# test/82/image_01598.jpg
# test/82/image_01603.jpg
# test/82/image_01661.jpg
# test/82/image_01594.jpg
# test/82/image_01618.jpg
# test/82/image_01614.jpg
# test/82/image_01653.jpg
# test/82/image_01662.jpg
# test/73/
# test/73/image_00258.jpg
# test/73/image_00426.jpg
# test/73/image_00337.jpg
# test/73/image_00369.jpg
# test/73/image_00291.jpg
# test/73/image_00319.jpg
# test/73/image_00353.jpg
# test/73/image_00324.jpg
# test/73/image_00277.jpg
# test/73/image_00394.jpg
# test/73/image_00335.jpg
# test/73/image_00345.jpg
# test/73/image_00401.jpg
# test/73/image_00288.jpg
# test/73/image_00320.jpg
# test/73/image_00303.jpg
# test/73/image_00400.jpg
# test/73/image_00282.jpg
# test/73/image_00409.jpg
# test/73/image_00284.jpg
# test/73/image_00445.jpg
# test/73/image_00330.jpg
# test/73/image_00389.jpg
# test/73/image_00260.jpg
# test/73/image_00349.jpg
# test/73/image_00365.jpg
# test/73/image_00294.jpg
# test/73/image_00387.jpg
# test/28/
# test/28/image_05242.jpg
# test/28/image_05214.jpg
# test/28/image_05277.jpg
# test/28/image_05253.jpg
# test/28/image_05270.jpg
# test/28/image_05230.jpg
# test/76/
# test/76/image_02550.jpg
# test/76/image_02472.jpg
# test/76/image_02484.jpg
# test/76/image_02479.jpg
# test/20/
# test/20/image_04938.jpg
# test/20/image_04910.jpg
# test/20/image_04912.jpg
# test/69/
# test/69/image_05971.jpg
# test/69/image_05994.jpg
# test/69/image_05959.jpg
# test/75/
# test/75/image_02167.jpg
# test/75/image_02088.jpg
# test/75/image_02115.jpg
# test/75/image_02085.jpg
# test/75/image_02119.jpg
# test/75/image_02135.jpg
# test/75/image_02144.jpg
# test/75/image_02157.jpg
# test/75/image_02188.jpg
# test/75/image_02075.jpg
# test/75/image_02111.jpg
# test/75/image_02154.jpg
# test/75/image_02078.jpg
# test/34/
# test/34/image_06954.jpg
# test/34/image_06929.jpg
# test/34/image_06941.jpg
# test/34/image_06933.jpg
# test/34/image_06961.jpg
# test/90/
# test/90/image_04417.jpg
# test/90/image_04430.jpg
# test/90/image_04420.jpg
# test/90/image_04473.jpg
# test/90/image_04426.jpg
# test/90/image_04458.jpg
# test/90/image_04428.jpg
# test/90/image_04469.jpg
# test/90/image_04468.jpg
# test/90/image_04432.jpg
# test/90/image_04407.jpg
# test/90/image_04405.jpg
# test/90/image_04459.jpg
# test/90/image_04431.jpg
# test/8/
# test/8/image_03347.jpg
# test/8/image_03364.jpg
# test/8/image_03320.jpg
# test/8/image_03319.jpg
# test/8/image_03314.jpg
# test/8/image_03357.jpg
# test/8/image_03291.jpg
# test/8/image_03299.jpg
# test/8/image_03359.jpg
# test/8/image_03295.jpg
# test/17/
# test/17/image_03855.jpg
# test/17/image_03906.jpg
# test/17/image_03861.jpg
# test/17/image_03830.jpg
# test/17/image_03893.jpg
# test/17/image_03864.jpg
# test/17/image_03911.jpg
# test/17/image_03846.jpg
# test/17/image_03872.jpg
# test/57/
# test/57/image_08144.jpg
# test/57/image_08127.jpg
# test/57/image_07234.jpg
# test/57/image_07242.jpg
# test/57/image_08133.jpg
# test/57/image_08134.jpg
# test/57/image_07250.jpg
# test/57/image_07266.jpg
# test/57/image_08129.jpg
# test/57/image_07267.jpg
# test/57/image_07241.jpg
# test/95/
# test/95/image_07584.jpg
# test/95/image_07508.jpg
# test/95/image_07487.jpg
# test/95/image_07470.jpg
# test/95/image_07561.jpg
# test/95/image_07550.jpg
# test/95/image_07472.jpg
# test/95/image_07573.jpg
# test/95/image_07468.jpg
# test/95/image_07519.jpg
# test/95/image_07551.jpg
# test/95/image_07536.jpg
# test/95/image_07505.jpg
# test/95/image_07514.jpg
# test/89/
# test/89/image_00699.jpg
# test/89/image_00645.jpg
# test/89/image_00724.jpg
# test/89/image_00726.jpg
# test/89/image_00755.jpg
# test/89/image_00740.jpg
# test/89/image_00745.jpg
# test/89/image_00676.jpg
# test/89/image_00654.jpg
# test/89/image_00634.jpg
# test/89/image_00708.jpg
# test/89/image_00610.jpg
# test/89/image_00756.jpg
# test/89/image_00779.jpg
# test/89/image_00617.jpg
# test/51/
# test/51/image_03985.jpg
# test/51/image_03939.jpg
# test/51/image_01370.jpg
# test/51/image_01328.jpg
# test/51/image_01388.jpg
# test/51/image_03954.jpg
# test/51/image_03980.jpg
# test/51/image_03984.jpg
# test/51/image_01316.jpg
# test/51/image_01340.jpg
# test/51/image_01474.jpg
# test/51/image_01314.jpg
# test/51/image_01468.jpg
# test/51/image_01406.jpg
# test/51/image_01362.jpg
# test/51/image_03968.jpg
# test/51/image_03926.jpg
# test/51/image_03973.jpg
# test/51/image_03960.jpg
# test/51/image_01335.jpg
# test/51/image_01457.jpg
# test/51/image_03989.jpg
# test/51/image_03986.jpg
# test/51/image_01407.jpg
# test/72/
# test/72/image_03633.jpg
# test/72/image_03599.jpg
# test/72/image_03547.jpg
# test/72/image_03603.jpg
# test/72/image_03625.jpg
# test/72/image_03575.jpg
# test/72/image_03593.jpg
# test/72/image_03624.jpg
# test/72/image_03613.jpg
# test/72/image_03635.jpg
# test/72/image_03628.jpg
# test/84/
# test/84/image_02576.jpg
# test/84/image_02563.jpg
# test/84/image_02572.jpg
# test/84/image_02615.jpg
# test/84/image_02583.jpg
# test/84/image_02586.jpg
# test/84/image_02613.jpg
# test/84/image_02557.jpg
# test/84/image_02568.jpg
# test/84/image_02581.jpg
# test/52/
# test/52/image_04169.jpg
# test/52/image_04167.jpg
# test/52/image_04181.jpg
# test/52/image_04168.jpg
# test/52/image_04240.jpg
# test/52/image_04160.jpg
# test/52/image_04221.jpg
# test/52/image_04200.jpg
# test/9/
# test/9/image_06410.jpg
# test/9/image_06413.jpg
# test/24/
# test/24/image_06849.jpg
# test/24/image_06815.jpg
# test/40/
# test/40/image_04586.jpg
# test/40/image_04568.jpg
# test/40/image_04573.jpg
# test/40/image_04582.jpg
# test/40/image_04588.jpg
# test/40/image_04563.jpg
# test/40/image_04609.jpg
# test/40/image_04587.jpg
# test/91/
# test/91/image_04856.jpg
# test/91/image_04851.jpg
# test/91/image_04883.jpg
# test/91/image_04875.jpg
# test/91/image_04870.jpg
# test/91/image_04890.jpg
# test/91/image_04860.jpg
# test/91/image_08061.jpg
# test/64/
# test/64/image_06104.jpg
# test/64/image_06099.jpg
# test/64/image_06134.jpg
# test/64/image_06138.jpg
# test/64/image_06130.jpg
# test/53/
# test/53/image_03718.jpg
# test/53/image_03714.jpg
# test/53/image_03645.jpg
# test/53/image_03689.jpg
# test/53/image_03652.jpg
# test/53/image_03649.jpg
# test/53/image_03669.jpg
# test/53/image_03653.jpg
# test/53/image_03672.jpg
# test/53/image_03717.jpg
# test/53/image_03712.jpg
# test/53/image_03662.jpg
# test/53/image_03724.jpg
# test/53/image_03677.jpg
# test/81/
# test/81/image_00926.jpg
# test/81/image_00869.jpg
# test/81/image_00814.jpg
# test/81/image_00833.jpg
# test/81/image_00815.jpg
# test/81/image_00826.jpg
# test/81/image_00946.jpg
# test/81/image_00888.jpg
# test/81/image_00798.jpg
# test/81/image_00825.jpg
# test/81/image_00818.jpg
# test/81/image_00828.jpg
# test/81/image_00898.jpg
# test/37/
# test/37/image_03783.jpg
# test/37/image_03811.jpg
# test/37/image_03821.jpg
# test/37/image_03734.jpg
# test/37/image_03741.jpg
# test/37/image_03807.jpg
# test/37/image_03815.jpg
# test/37/image_03789.jpg
# test/22/
# test/22/image_05366.jpg
# test/22/image_05391.jpg
# test/22/image_05362.jpg
# test/22/image_05360.jpg
# test/30/
# test/30/image_03528.jpg
# test/30/image_03482.jpg
# test/30/image_03538.jpg
# test/30/image_03509.jpg
# test/30/image_03484.jpg
# test/30/image_03489.jpg
# test/30/image_03481.jpg
# test/30/image_03506.jpg
# test/30/image_03488.jpg
# test/30/image_03542.jpg
# test/30/image_03510.jpg
# test/30/image_03541.jpg
# test/30/image_03466.jpg
# test/30/image_03512.jpg
# test/44/
# test/44/image_01560.jpg
# test/44/image_01512.jpg
# test/44/image_01515.jpg
# test/44/image_01527.jpg
# test/44/image_01516.jpg
# test/44/image_01548.jpg
# test/44/image_01502.jpg
# test/44/image_01518.jpg
# test/44/image_01578.jpg
# test/44/image_01530.jpg
# test/44/image_01564.jpg
# test/78/
# test/78/image_01888.jpg
# test/78/image_01848.jpg
# test/78/image_01931.jpg
# test/78/image_01843.jpg
# test/78/image_01855.jpg
# test/78/image_01953.jpg
# test/78/image_01893.jpg
# test/78/image_01903.jpg
# test/78/image_01874.jpg
# test/78/image_01928.jpg
# test/78/image_01919.jpg
# test/78/image_01949.jpg
# test/78/image_01830.jpg
# test/78/image_01856.jpg
# test/41/
# test/41/image_02266.jpg
# test/41/image_02237.jpg
# test/41/image_02302.jpg
# test/41/image_02257.jpg
# test/41/image_02193.jpg
# test/41/image_02305.jpg
# test/41/image_02261.jpg
# test/41/image_02245.jpg
# test/41/image_02270.jpg
# test/41/image_02263.jpg
# test/41/image_02222.jpg
# test/41/image_02200.jpg
# test/41/image_02306.jpg
# test/41/image_02251.jpg
# test/33/
# test/33/image_06456.jpg
# test/33/image_06457.jpg
# test/33/image_06454.jpg
# test/33/image_06479.jpg
# test/33/image_06486.jpg
# test/33/image_06478.jpg
# test/33/image_06470.jpg
# test/33/image_06460.jpg
# test/58/
# test/58/image_02677.jpg
# test/58/image_02687.jpg
# test/58/image_02695.jpg
# test/58/image_02738.jpg
# test/58/image_02752.jpg
# test/58/image_02663.jpg
# test/58/image_02672.jpg
# test/58/image_02743.jpg
# test/58/image_02737.jpg
# test/58/image_02681.jpg
# test/58/image_02721.jpg
# test/58/image_02694.jpg
# test/58/image_02719.jpg
# test/58/image_02722.jpg
# test/83/
# test/83/image_01789.jpg
# test/83/image_01737.jpg
# test/83/image_01742.jpg
# test/83/image_01810.jpg
# test/83/image_01774.jpg
# test/83/image_01748.jpg
# test/83/image_01805.jpg
# test/83/image_01759.jpg
# test/83/image_01809.jpg
# test/83/image_01755.jpg
# test/83/image_01777.jpg
# test/83/image_01735.jpg
# test/83/image_01818.jpg
# test/83/image_01770.jpg
# test/26/
# test/26/image_06514.jpg
# test/26/image_06500.jpg
# test/26/image_06526.jpg
# test/26/image_06498.jpg
# test/26/image_06497.jpg
# test/43/
# test/43/image_02426.jpg
# test/43/image_02335.jpg
# test/43/image_02370.jpg
# test/43/image_02431.jpg
# test/43/image_02349.jpg
# test/43/image_02412.jpg
# test/43/image_02369.jpg
# test/43/image_02433.jpg
# test/43/image_02400.jpg
# test/43/image_02394.jpg
# test/43/image_02365.jpg
# test/43/image_02386.jpg
# test/43/image_02435.jpg
# test/43/image_02329.jpg
# test/43/image_02371.jpg
# test/43/image_02346.jpg
# test/96/
# test/96/image_07596.jpg
# test/96/image_07676.jpg
# test/96/image_07668.jpg
# test/96/image_07597.jpg
# test/96/image_07683.jpg
# test/96/image_07672.jpg
# test/96/image_07622.jpg
# test/96/image_07606.jpg
# test/96/image_07646.jpg
# test/25/
# test/25/image_06582.jpg
# test/25/image_06593.jpg
# test/25/image_06580.jpg
# test/25/image_06583.jpg
# test/25/image_06611.jpg
# test/39/
# test/39/image_07018.jpg
# test/39/image_07010.jpg
# test/39/image_07016.jpg
# test/39/image_07035.jpg
# test/39/image_07043.jpg
# test/65/
# test/65/image_03211.jpg
# test/65/image_03269.jpg
# test/65/image_03197.jpg
# test/65/image_03188.jpg
# test/65/image_03258.jpg
# test/65/image_03243.jpg
# test/65/image_03252.jpg
# test/61/
# test/61/image_06290.jpg
# test/61/image_06279.jpg
# test/61/image_06271.jpg
# test/61/image_06248.jpg
# test/61/image_06251.jpg
# test/61/image_06266.jpg
# test/61/image_06249.jpg
# test/61/image_06284.jpg
# test/55/
# test/55/image_04701.jpg
# test/55/image_04740.jpg
# test/55/image_04747.jpg
# test/55/image_04742.jpg
# test/55/image_04707.jpg
# test/55/image_04731.jpg
# test/55/image_04733.jpg
# test/92/
# test/92/image_03049.jpg
# test/92/image_03054.jpg
# test/92/image_03041.jpg
# test/92/image_03056.jpg
# test/92/image_03052.jpg
# test/92/image_03039.jpg
# test/92/image_03032.jpg
# test/92/image_03075.jpg
# test/92/image_03058.jpg
# test/92/image_03044.jpg
# test/92/image_03048.jpg
# test/87/
# test/87/image_05462.jpg
# test/87/image_05469.jpg
# test/87/image_05493.jpg
# test/87/image_05466.jpg
# test/87/image_05488.jpg
# test/87/image_05485.jpg
# test/71/
# test/71/image_04555.jpg
# test/71/image_04488.jpg
# test/71/image_04519.jpg
# test/71/image_04512.jpg
# test/71/image_04557.jpg
# test/71/image_04514.jpg
# test/71/image_04515.jpg
# test/71/image_04524.jpg
# test/71/image_04482.jpg
# test/80/
# test/80/image_02041.jpg
# test/80/image_02062.jpg
# test/80/image_01996.jpg
# test/80/image_02049.jpg
# test/80/image_02051.jpg
# test/80/image_02055.jpg
# test/80/image_02023.jpg
# test/80/image_01983.jpg
# test/80/image_01993.jpg
# test/80/image_02020.jpg
# test/80/image_01990.jpg
# test/23/
# test/23/image_03414.jpg
# test/23/image_03390.jpg
# test/23/image_03442.jpg
# test/23/image_03454.jpg
# test/23/image_03409.jpg
# test/23/image_03440.jpg
# test/23/image_03382.jpg
# test/62/
# test/62/image_08172.jpg
# test/62/image_07269.jpg
# test/62/image_08177.jpg
# test/62/image_07276.jpg
# test/102/
# test/102/image_08015.jpg
# test/102/image_08042.jpg
# test/102/image_08023.jpg
# test/102/image_08004.jpg
# test/102/image_08012.jpg
# test/102/image_08030.jpg
# test/11/
# test/11/image_03098.jpg
# test/11/image_03177.jpg
# test/11/image_03151.jpg
# test/11/image_03141.jpg
# test/11/image_03115.jpg
# test/11/image_03147.jpg
# test/11/image_03165.jpg
# test/11/image_03176.jpg
# test/11/image_03130.jpg
# test/59/
# test/59/image_05039.jpg
# test/59/image_05067.jpg
# test/59/image_05033.jpg
# test/59/image_05064.jpg
# test/59/image_05052.jpg
# test/59/image_05020.jpg
# test/59/image_05038.jpg
# test/19/
# test/19/image_06170.jpg
# test/19/image_06175.jpg
# test/19/image_06197.jpg
# test/19/image_06186.jpg
# test/19/image_06159.jpg
# test/19/image_06196.jpg
# test/19/image_06155.jpg
# test/4/
# test/4/image_05640.jpg
# test/4/image_05653.jpg
# test/4/image_05678.jpg
# test/4/image_05636.jpg
# test/4/image_05658.jpg
# test/4/image_05637.jpg
# test/45/
# test/45/image_07139.jpg
# test/45/image_07140.jpg
# test/45/image_07142.jpg
# test/14/
# test/14/image_06091.jpg
# test/14/image_06083.jpg
# test/14/image_06052.jpg
# test/50/
# test/50/image_06547.jpg
# test/50/image_06541.jpg
# test/50/image_06319.jpg
# test/50/image_06320.jpg
# test/50/image_06318.jpg
# test/50/image_06546.jpg
# test/50/image_06297.jpg
# test/50/image_06321.jpg
# test/70/
# test/70/image_05308.jpg
# test/70/image_05330.jpg
# test/70/image_05324.jpg
# test/70/image_05331.jpg
# test/47/
# test/47/image_04993.jpg
# test/47/image_05013.jpg
# test/47/image_04966.jpg
# test/68/
# test/68/image_05956.jpg
# test/68/image_05927.jpg
# test/68/image_05903.jpg
# test/101/
# test/101/image_07949.jpg
# test/101/image_07952.jpg
# test/101/image_07988.jpg
# test/101/image_07983.jpg
# test/100/
# test/100/image_07899.jpg
# test/100/image_07902.jpg
# test/100/image_07896.jpg
# test/100/image_07939.jpg
# test/100/image_07936.jpg
# test/100/image_07897.jpg
# test/100/image_07926.jpg
# test/100/image_07938.jpg
# test/67/
# test/67/image_07056.jpg
# test/67/image_07080.jpg
# test/67/image_07082.jpg
# test/67/image_07079.jpg
# test/98/
# test/98/image_07753.jpg
# test/98/image_07787.jpg
# test/98/image_07758.jpg
# test/98/image_07777.jpg
# test/6/
# test/6/image_07185.jpg
# test/6/image_07199.jpg
# test/6/image_08106.jpg
# test/6/image_07173.jpg
# test/6/image_07191.jpg
# test/6/image_07198.jpg
# test/6/image_07182.jpg
# test/6/image_07181.jpg
# test/6/image_08108.jpg
# test/38/
# test/38/image_05824.jpg
# test/38/image_05799.jpg
# test/38/image_05833.jpg
# test/38/image_05825.jpg
# test/38/image_05797.jpg
# test/38/image_05806.jpg
# test/38/image_05796.jpg
# test/38/image_05812.jpg
# test/7/
# test/7/image_07219.jpg
# test/7/image_07215.jpg
# test/7/image_07218.jpg
# test/7/image_07211.jpg
# test/7/image_08099.jpg
# test/7/image_08104.jpg
# test/18/
# test/18/image_04322.jpg
# test/18/image_04254.jpg
# test/18/image_04256.jpg
# test/18/image_04272.jpg
# test/18/image_04292.jpg
# test/18/image_04277.jpg
# test/29/
# test/29/image_04083.jpg
# test/29/image_04146.jpg
# test/29/image_04145.jpg
# test/29/image_04142.jpg
# test/29/image_04090.jpg
# test/29/image_04137.jpg
# test/29/image_04095.jpg
# test/29/image_04112.jpg
# test/29/image_04124.jpg
# test/60/
# test/60/image_02987.jpg
# test/60/image_03026.jpg
# test/60/image_02971.jpg
# test/60/image_02933.jpg
# test/60/image_02977.jpg
# test/60/image_02978.jpg
# test/60/image_02958.jpg
# test/60/image_02932.jpg
# test/60/image_03000.jpg
# test/60/image_03008.jpg
# test/49/
# test/49/image_06202.jpg
# test/49/image_06215.jpg
# test/49/image_06213.jpg
# test/97/
# test/97/image_07737.jpg
# test/97/image_07708.jpg
# test/97/image_07719.jpg
# test/97/image_07696.jpg
# test/97/image_07709.jpg
# test/85/
# test/85/image_04808.jpg
# test/85/image_04814.jpg
# test/85/image_04825.jpg
# test/85/image_04801.jpg
# test/85/image_04810.jpg
# test/85/image_04786.jpg
# test/85/image_04819.jpg
# test/85/image_04805.jpg
# test/85/image_04806.jpg
# test/85/image_04797.jpg
# test/48/
# test/48/image_04627.jpg
# test/48/image_04671.jpg
# test/48/image_04665.jpg
# test/48/image_04663.jpg
# test/48/image_04667.jpg
# test/93/
# test/93/image_06037.jpg
# test/93/image_06014.jpg
# test/93/image_06033.jpg
# test/93/image_06017.jpg
# test/93/image_06021.jpg
# test/93/image_06031.jpg
# test/35/
# test/35/image_08088.jpg
# test/35/image_07006.jpg
# test/35/image_06986.jpg
# test/35/image_06992.jpg
# test/35/image_06984.jpg
# test/35/image_08084.jpg
# test/13/
# test/13/image_05787.jpg
# test/13/image_05745.jpg
# test/13/image_05775.jpg
# test/13/image_05767.jpg
# test/13/image_05769.jpg
# test/13/image_05761.jpg
# test/79/
# test/79/image_06708.jpg
# test/79/image_06726.jpg
# test/79/image_06720.jpg
# test/56/
# test/56/image_02825.jpg
# test/56/image_02772.jpg
# test/56/image_02844.jpg
# test/56/image_02841.jpg
# test/56/image_02808.jpg
# test/56/image_02779.jpg
# test/56/image_02785.jpg
# test/56/image_02821.jpg
# test/1/
# test/1/image_06760.jpg
# test/1/image_06754.jpg
# test/1/image_06752.jpg
# test/1/image_06743.jpg
# test/1/image_06764.jpg
# test/31/
# test/31/image_08070.jpg
# test/31/image_06903.jpg
# test/54/
# test/54/image_05430.jpg
# test/54/image_05402.jpg
# test/54/image_05413.jpg
# test/54/image_05440.jpg
# test/63/
# test/63/image_05882.jpg
# test/63/image_05875.jpg
# test/63/image_05878.jpg
# test/63/image_05890.jpg
# test/99/
# test/99/image_07854.jpg
# test/99/image_07840.jpg
# test/99/image_07838.jpg
# test/99/image_07833.jpg
# test/99/image_07857.jpg
# test/99/image_07874.jpg
# test/99/image_07871.jpg
# test/15/
# test/15/image_06360.jpg
# test/15/image_06374.jpg
# test/15/image_06369.jpg
# test/15/image_06351.jpg
# test/21/
# test/21/image_06805.jpg
# test/21/image_06807.jpg
# test/10/
# test/10/image_07117.jpg
# test/10/image_07090.jpg
# test/10/image_07104.jpg
# test/86/
# test/86/image_02865.jpg
# test/86/image_02910.jpg
# test/86/image_02912.jpg
# test/86/image_02873.jpg
# test/86/image_02893.jpg
# test/66/
# test/66/image_05537.jpg
# test/66/image_05549.jpg
# test/66/image_05582.jpg
# test/66/image_05562.jpg
# test/27/
# test/27/image_06871.jpg
# test/27/image_06887.jpg
# test/27/image_06864.jpg
# test/3/
# test/3/image_06641.jpg
# test/3/image_06634.jpg
# cat_to_name.json
# flower_data
# flower_data.zip
# sample_data
# test
# Udacity-Course

# %%
test_dir = 'test'

test_transforms = transforms.Compose([
                       transforms.Resize(256),
                       transforms.CenterCrop(224),
                       transforms.ToTensor(),
                       transforms.Normalize([0.485, 0.456, 0.406],[0.229, 0.224, 0.225])])

test_data = datasets.ImageFolder(test_dir,transform=test_transforms)

test_loader = torch.utils.data.DataLoader(test_data,batch_size=batch_size,num_workers=num_workers,shuffle=True)

# %%
def test_accuracy(model, test_loader):

    model.eval()
    
    if train_on_gpu:
      model.cuda()

    with torch.no_grad():
        accuracy = 0
        for images, labels in iter(test_loader):
          if train_on_gpu:
            images, labels = images.cuda(), labels.cuda()
          output = model.forward(images)
          probabilities = torch.exp(output)        
          equality = (labels.data == probabilities.max(dim=1)[1])     
          accuracy += equality.type(torch.FloatTensor).mean()
        
        print("Test Accuracy: {}".format(accuracy/len(test_loader)))    
        
        
test_accuracy(model, test_loader)
# Out:
# Test Accuracy: 0.8948653340339661

# %% [markdown]
# nb : you can make it better, by unfreezing the layers as parts, once the training proceeds.
# Let some surprise remain.

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
 # TODO: Save the checkpoint 
def save_checkpoint(model):
  model.class_to_idx = train_data.class_to_idx
  
  checkpoint = {'arch' : 'vgg16',
                'class_to_idx':model.class_to_idx,
                'model_state_dict':model.state_dict()}
  torch.save(checkpoint,'checkpoint.pth')


save_checkpoint(model)

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# TODO: Write a function that loads a checkpoint and rebuilds the model
def load_checkpoint(checkpoint_path):
  
  checkpoint = torch.load(checkpoint_path)
  print(checkpoint.keys())
  if checkpoint['arch'] == 'vgg16':
    model = models.vgg16(pretrained=True)
      
    for param in model.parameters():
      param.requires_grad = False
  else:
    print('Model not Identified')
  
  model.class_to_idx = checkpoint['class_to_idx']
  
  classifier = nn.Sequential(nn.Linear(25088,4096),
                                 nn.ReLU(),
                                 nn.Dropout(0.5),
                                 nn.Linear(4096,102))
  model.classifier = classifier
  
  model.load_state_dict(checkpoint['model_state_dict'],strict=False)
  
  return model      
        
load_checkpoint('checkpoint.pth')
# Out:
# dict_keys(['arch', 'class_to_idx', 'model_state_dict'])
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.5)
#     (3): Linear(in_features=4096, out_features=102, bias=True)
#   )
# )

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
def process_image(image_path):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''
    
    # TODO: Process a PIL image for use in a PyTorch model
    pil_image = Image.open(image_path)
    
    # resizing image
    if pil_image.size[0] > pil_image.size[1]:
        pil_image.thumbnail((5000, 256))
    else:
        pil_image.thumbnail((256, 5000))
        
    # Crop 
    left_margin = (pil_image.width-224)/2
    bottom_margin = (pil_image.height-224)/2
    right_margin = left_margin + 224
    top_margin = bottom_margin + 224
    
    pil_image = pil_image.crop((left_margin, bottom_margin, right_margin, top_margin))
    
    # Normalize
    np_image = np.array(pil_image)/255
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    np_image = (np_image - mean) / std
    
    # PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array
    # Color channel needs to be first; retain the order of the other two dimensions.
    np_image = np_image.transpose((2, 0, 1))
    
    return np_image

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.transpose((1, 2, 0))
    
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax
  
image = process_image('test/15/image_06369.jpg')
imshow(image)

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
def predict(image_path, model, topk=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    '''
    # TODO: Implement the code to predict the class from an image file
    image = process_image(image_path)
    
    image = torch.from_numpy(image)
    
    if train_on_gpu:
      image = image.cuda()
      model = model.cuda()
    
    image = image.unsqueeze(0)
    image = image.float()
    
    pred = model.forward(image)
    
    top_probabilities, top_indices = pred.topk(topk)
    
    # Convert to lists
    top_probabilities = top_probabilities.detach().type(torch.FloatTensor).numpy().tolist()[0] 
    top_indices = top_indices.detach().type(torch.FloatTensor).numpy().tolist()[0] 
    
    idx_to_class = {value: key for key, value in model.class_to_idx.items()}
    
    top_classes = [idx_to_class[index] for index in top_indices]
    
    return top_probabilities, top_classes
    
probs, classes = predict('test/15/image_06369.jpg', model)   
print(probs)
print(classes)
# Out:
# [18.53563690185547, 12.326920509338379, 8.84118366241455, 8.654741287231445, 8.117034912109375]
# ['15', '42', '48', '90', '65']

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the validation accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='https://github.com/udacity/pytorch_challenge/blob/master/assets/inference_example.png?raw=1' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
# TODO: Display an image along with the top 5 classes

# input image
plt.figure(figsize = (6,10))
plot_1 = plt.subplot(2,1,1)

image = process_image('test/15/image_06369.jpg')

flower_title = cat_to_name['15']

imshow(image, plot_1, title=flower_title);

# class integer encoding to actual flower names
flower_names = [cat_to_name[i] for i in classes]

# Plot the probabilities for the top 5 classes as a bar graph
plt.subplot(2,1,2)

sb.barplot(x=probs, y=flower_names, color=sb.color_palette()[0]);

plt.show()
